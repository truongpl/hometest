# %%
import openai
openai.api_key="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"

# %%
training_response = openai.File.create(file=open("train_v1.jsonl", "rb"), purpose='fine-tune')
validation_response = openai.File.create(file=open("val_v1.jsonl", "rb"), purpose="fine-tune")

training_file_id = training_response["id"]
validation_file_id = validation_response["id"]

# %%
print(training_file_id, validation_file_id)
training_response
validation_response
# Out:
# file-R4KNSpxpnOYhriqbHlyfkHkN file-s8E1QpZnMNk23NtMzkFc54sC
# <File file id=file-s8E1QpZnMNk23NtMzkFc54sC at 0x7fe333d92b80> JSON: {
#   "object": "file",
#   "id": "file-s8E1QpZnMNk23NtMzkFc54sC",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 72445,
#   "created_at": 1694604857,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
is_training = False
import time
while is_training == False:
    try:
        response = openai.FineTuningJob.create(
            training_file=training_file_id,
            validation_file=validation_file_id,
            model="gpt-3.5-turbo",
            suffix="PdM",
            hyperparameters={"n_epochs":2}
        )
        
        job_id = response["id"]
        
        print("Job ID:", response["id"])
        print("Status:", response["status"])

        is_training = True
    except Exception as e:
        print("Cannot train by open ai error ", e)

    time.sleep(120) # Sleep 1 minutes
# Out:
# Job ID: ftjob-kWJwtXGxXV9BG9BXY7AyqgtG
# Status: created

# %%
response
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-kWJwtXGxXV9BG9BXY7AyqgtG at 0x7fe333ddeae0> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-kWJwtXGxXV9BG9BXY7AyqgtG",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1694611599,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-UjMKgymf7EB330zzheomL80t",
#   "result_files": [],
#   "status": "created",
#   "validation_file": "file-s8E1QpZnMNk23NtMzkFc54sC",
#   "training_file": "file-R4KNSpxpnOYhriqbHlyfkHkN",
#   "hyperparameters": {
#     "n_epochs": 2
#   },
#   "trained_tokens": null,
#   "error": null
# }

# %%
# List 10 fine-tuning jobs
openai.FineTuningJob.list(limit=10)

# Retrieve the state of a fine-tune
openai.FineTuningJob.retrieve("ftjob-kWJwtXGxXV9BG9BXY7AyqgtG")
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-kWJwtXGxXV9BG9BXY7AyqgtG at 0x7fe334009180> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-kWJwtXGxXV9BG9BXY7AyqgtG",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1694611599,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-UjMKgymf7EB330zzheomL80t",
#   "result_files": [],
#   "status": "running",
#   "validation_file": "file-s8E1QpZnMNk23NtMzkFc54sC",
#   "training_file": "file-R4KNSpxpnOYhriqbHlyfkHkN",
#   "hyperparameters": {
#     "n_epochs": 2
#   },
#   "trained_tokens": null,
#   "error": null
# }

# %%
openai.FineTuningJob.list_events(id="ftjob-kWJwtXGxXV9BG9BXY7AyqgtG", limit=20)
# Out:
# <OpenAIObject list at 0x7fe333d14cc0> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job.event",
#       "id": "ftevent-dgpVM38m06FXJ5bYnNBfYhdb",
#       "created_at": 1694615240,
#       "level": "info",
#       "message": "The job has successfully completed",
#       "data": {},
#       "type": "message"
#     },
#     {
#       "object": "fine_tuning.job.event",
#       "id": "ftevent-jRrOldfiLqb8wfp7Zn0iXaUm",
#       "created_at": 1694615239,
#       "level": "info",
#       "message": "New fine-tuned model created: ft:gpt-3.5-turbo-0613:ai4s:pdm:7yL7mvqc",
#       "data": {},
#       "type": "message"
#     },
#     {
#       "object": "fine_tuning.job.event",
#       "id": "ftevent-4xfStdHHYZWrD0JxKVMR03Sa",
#       "created_at": 1694615144,
#       "level": "info",
#       "message": "Step 1700/1750: training loss=0.00",
#       "data": {
#         "step": 1700,
#         "train_loss": 3.814697322468419e-07,
# ...
